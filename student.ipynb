# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name: BAKER OTIENO OYUGI
# * Student pace:  part time
# * Scheduled project review date/time:
# * Instructor name:
# * Blog post URL:

# %%
# Your code here - remember to use markdown cells for comments as well!

# %% [markdown]
# MICROSOFT-MOVIE-RECOMMENDATION-EXPLORATORY-DATA-ANALYSIS

# %% [markdown]
# Microsoft, a global technology leader, is seeking to diversify its business portfolio by entering the movie production industry. This strategic move aims to leverage the growing demand for high-quality content and capitalize on the company's creative potential. The analysis conducted on various datasets provides actionable insights and recommendations to ensure a seamless integration into the movie production market.

# %% [markdown]
# Import Library

# %%
#Importing the datasets that I will be using for the analysis
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %% [markdown]
# Uploading CSV files

# %%
#load dataset
df=pd.read_csv(r"bom.movie_gross.csv")

# %%
df.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
#load dataset
df_names=pd.read_csv(r"name.basics.csv")

# %% [markdown]
# Data Preprocessing

# %%
#create an empty dataframe
merged_data = pd.DataFrame()

# %%
# merging my title.basics, title.crew, title.principals, title.ratings movie datasets
folder_path = r"C:\Users\OTIENO BAKER OYUGI\Desktop\Moringa_school_phase_1_project\data"  

for filename in os.listdir(folder_path):
    if filename.endswith(".csv"):
        file_path = os.path.join(folder_path, filename)

        # Load the CSV file into a DataFrame
        current_data = pd.read_csv(file_path)

        # Merge data
        if merged_data.empty:
            merged_data = current_data
        else:
            merged_data = pd.merge(merged_data, current_data, on="tconst", how="outer")

# %%
merged_data.head()
# Out:
#       tconst primary_title original_title  start_year  runtime_minutes  \
# 0  tt0063540     Sunghursh      Sunghursh        2013            175.0
# 1  tt0063540     Sunghursh      Sunghursh        2013            175.0
# 2  tt0063540     Sunghursh      Sunghursh        2013            175.0
# 3  tt0063540     Sunghursh      Sunghursh        2013            175.0
# 4  tt0063540     Sunghursh      Sunghursh        2013            175.0
#
#                genres  directors                                  writers  \
# 0  Action,Crime,Drama  nm0712540  nm0023551,nm1194313,nm0347899,nm1391276
# 1  Action,Crime,Drama  nm0712540  nm0023551,nm1194313,nm0347899,nm1391276
# 2  Action,Crime,Drama  nm0712540  nm0023551,nm1194313,nm0347899,nm1391276
# 3  Action,Crime,Drama  nm0712540  nm0023551,nm1194313,nm0347899,nm1391276
# 4  Action,Crime,Drama  nm0712540  nm0023551,nm1194313,nm0347899,nm1391276
#
#    ordering     nconst  category  job                       characters  \
# ...

# %%
df.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
#Confirming if my dataset was merged correctly
df_names.head()
# Out:
#       nconst       primary_name  birth_year  death_year  \
# 0  nm0061671  Mary Ellen Bauder         NaN         NaN
# 1  nm0061865       Joseph Bauer         NaN         NaN
# 2  nm0062070         Bruce Baum         NaN         NaN
# 3  nm0062195       Axel Baumann         NaN         NaN
# 4  nm0062798        Pete Baxter         NaN         NaN
#
#                                  primary_profession  \
# 0         miscellaneous,production_manager,producer
# 1        composer,music_department,sound_department
# 2                        miscellaneous,actor,writer
# 3  camera_department,cinematographer,art_department
# 4  production_designer,art_department,set_decorator
#
#                           known_for_titles
# 0  tt0837562,tt2398241,tt0844471,tt0118553
# 1  tt0896534,tt6791238,tt0287072,tt1682940
# 2  tt1470654,tt0363631,tt0104030,tt0102898
# 3  tt0114371,tt2004304,tt1618448,tt1224387
# 4  tt0452644,tt0452692,tt3458030,tt2178256

# %%
print(merged_data.head())
# Out:
#       tconst primary_title original_title  start_year  runtime_minutes  \
# 0  tt0063540     Sunghursh      Sunghursh        2013            175.0
# 1  tt0063540     Sunghursh      Sunghursh        2013            175.0
# 2  tt0063540     Sunghursh      Sunghursh        2013            175.0
# 3  tt0063540     Sunghursh      Sunghursh        2013            175.0
# 4  tt0063540     Sunghursh      Sunghursh        2013            175.0
#
#                genres  directors                                  writers  \
# 0  Action,Crime,Drama  nm0712540  nm0023551,nm1194313,nm0347899,nm1391276
# 1  Action,Crime,Drama  nm0712540  nm0023551,nm1194313,nm0347899,nm1391276
# 2  Action,Crime,Drama  nm0712540  nm0023551,nm1194313,nm0347899,nm1391276
# 3  Action,Crime,Drama  nm0712540  nm0023551,nm1194313,nm0347899,nm1391276
# 4  Action,Crime,Drama  nm0712540  nm0023551,nm1194313,nm0347899,nm1391276
#
#    ordering     nconst  category  job                       characters  \
# ...

# %%
#getting a random sample of my merged dataset
merged_data.sample(10)
# Out:
#             tconst                         primary_title  \
# 964529   tt8629592                             Last Call
# 566007   tt4353876                     Trip Along Exodus
# 943347   tt8285280                 Chaos in the Spectrum
# 629874   tt4935462                         Amazing Grace
# 238251   tt2190820              Charlie Kay Chakkar Mein
# 1026910  tt9828810                        Angara Dangara
# 406719   tt3182312                           The Icy Sun
# 578303   tt4469360                    Il seme ed il mare
# 856728   tt7156760  Presence III: This Side of the Other
# 1017584  tt9617484          Nothing Fancy: Diana Kennedy
#
#                                original_title  start_year  runtime_minutes  \
# 964529                              Last Call        2019              NaN
# 566007                      Trip Along Exodus        2014            120.0
# 943347                  Chaos in the Spectrum        2018              NaN
# ...

# %%
#confirming the data info for my merged dataset
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1030876 entries, 0 to 1030875
# Data columns (total 15 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   tconst           1030876 non-null  object
#  1   primary_title    1030876 non-null  object
#  2   original_title   1030855 non-null  object
#  3   start_year       1030876 non-null  int64
#  4   runtime_minutes  828893 non-null   float64
#  5   genres           1007380 non-null  object
#  6   directors        1014587 non-null  object
#  7   writers          861040 non-null   object
#  8   ordering         1028186 non-null  float64
#  9   nconst           1028186 non-null  object
#  10  category         1028186 non-null  object
#  11  job              177684 non-null   object
#  12  characters       393360 non-null   object
#  13  averagerating    629926 non-null   float64
#  14  numvotes         629926 non-null   float64
# dtypes: float64(4), int64(1), object(10)
# ...

# %%
#changing merged data sets to objects
merged_data['runtime_minutes']=merged_data['runtime_minutes'].astype(str)
merged_data['start_year']=merged_data['start_year'].astype(str)
merged_data['ordering']=merged_data['ordering'].astype(str)
merged_data['averagerating']=merged_data['averagerating'].astype(str)
merged_data['numvotes']=merged_data['numvotes'].astype(str)

# %%
#reconfirming data info for my merged dataset
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1030876 entries, 0 to 1030875
# Data columns (total 15 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   tconst           1030876 non-null  object
#  1   primary_title    1030876 non-null  object
#  2   original_title   1030855 non-null  object
#  3   start_year       1030876 non-null  object
#  4   runtime_minutes  1030876 non-null  object
#  5   genres           1007380 non-null  object
#  6   directors        1014587 non-null  object
#  7   writers          861040 non-null   object
#  8   ordering         1030876 non-null  object
#  9   nconst           1028186 non-null  object
#  10  category         1028186 non-null  object
#  11  job              177684 non-null   object
#  12  characters       393360 non-null   object
#  13  averagerating    1030876 non-null  object
#  14  numvotes         1030876 non-null  object
# dtypes: object(15)
# memory usage: 125.8+ MB

# %%
#check missing data in my merged dataset
missing_data = merged_data.isna().sum()
print(missing_data)
# Out:
# tconst                  0
# primary_title           0
# original_title         21
# start_year              0
# runtime_minutes         0
# genres              23496
# directors           16289
# writers            169836
# ordering                0
# nconst               2690
# category             2690
# job                853192
# characters         637516
# averagerating           0
# numvotes                0
# dtype: int64

# %%
#checking unique datasets in my merged dataset
merged_data.nunique()
# Out:
# tconst             146144
# primary_title      136064
# original_title     137766
# start_year             19
# runtime_minutes       368
# genres               1085
# directors           98525
# writers             91920
# ordering               11
# nconst             604546
# category               12
# job                  2965
# characters         174762
# averagerating          92
# numvotes             7350
# dtype: int64

# %% [markdown]
# Genre-based content strategy
# We're digging into the 'genres' column to figure out which movie genres are the big crowd-pleasers. Whether it is action, comedy, or drama, we are identifying the genres that folks cannot get enough of, with a purpose of Identifying prevalent movie genres based on IMDB data. Provide recommendations for movie genre selection

# %%
#Identifying the unique columns in the merged dataset
unique_genres = merged_data['genres'].explode().unique()
print(unique_genres)
# Out:
# ['Action,Crime,Drama' 'Biography,Drama' 'Drama' ...
#  'Music,Musical,Reality-TV' 'Animation,Crime' 'Adventure,History,War']

# %%
#Identify missing data in the genre
print(merged_data['genres'].isnull().sum())
# Out:
# 23496

# %%
#replace the missing values with "Unknown"
merged_data['genres']= merged_data['genres'].fillna("Unknown")
merged_data.sample(5)
# Out:
#            tconst     primary_title    original_title start_year  \
# 509548  tt3887570  Beautiful Births  Beautiful Births       2014
# 530135  tt4067672              SILA              SILA       2015
# 614218  tt4791910       Macho Man 2       Macho Man 2       2017
# 225948  tt2142691       AKA Blondie       AKA Blondie       2012
# 349618  tt2757396             Lakmé             Lakmé       2011
#
#        runtime_minutes                      genres  directors  \
# 509548            59.0          Documentary,Family  nm6652088
# 530135            70.0  Adventure,Documentary,News  nm5182218
# 614218             nan                      Action  nm7405876
# 225948            52.0       Biography,Documentary  nm3282144
# 349618           180.0                       Music  nm0456706
#
#                                                   writers ordering     nconst  \
# 509548                                          nm6652088      5.0  nm6652088
# ...

# %%
#Identifying the different counts within the different genres
genre_counts = merged_data['genres'].value_counts()
print(genre_counts)
# Out:
# Drama                         174784
# Documentary                   170055
# Comedy                         76985
# Horror                         34431
# Comedy,Drama                   31283
#                                ...
# Action,Horror,Music                1
# Documentary,Musical,War            1
# Adventure,Animation,Crime          1
# Animation,Fantasy,Thriller         1
# Horror,Musical,Thriller            1
# Name: genres, Length: 1086, dtype: int64

# %%
merged_data['genres'] = merged_data['genres'].str.split(',')

# Use the explode function to create separate rows for each genre
merged_data = merged_data.explode('genres')

# Count the individual genres
genre_counts = merged_data['genres'].value_counts().reset_index()

# Rename the columns for clarity
genre_counts.columns = ['Genre', 'Count']

# Display the counts
print(genre_counts)
# Out:
#           Genre   Count
# 0         Drama  406468
# 1   Documentary  270855
# 2        Comedy  214243
# 3      Thriller  101863
# 4        Horror   88835
# 5        Action   86310
# 6       Romance   80517
# 7         Crime   56907
# 8     Biography   51752
# 9     Adventure   47714
# 10       Family   44885
# 11      Mystery   38071
# 12      History   37918
# 13        Music   28074
# 14      Fantasy   27978
# 15       Sci-Fi   27264
# 16      Unknown   23496
# 17    Animation   19821
# 18        Sport   15341
# 19      Musical   10718
# 20          War   10238
# 21         News    7441
# 22      Western    3735
# 23   Reality-TV     497
# 24    Talk-Show     223
# 25        Adult      69
# 26        Short      69
# 27    Game-Show      30

# %%
#creating a visualization using seaborn and matplotlib for my merged data set
plt.figure(figsize=(12, 6))
sns.barplot(data=genre_counts, x='Count', y='Genre')
# Customize the plot
plt.title('Count of Movie Genres')
plt.xlabel('Count')
plt.ylabel('Genre')

#rotate the x axis for readability
plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# From the above merged dataset graphical representation, we can observe that Drama movies followed by Documentary, then comedy followed by thriller movies are among the most streamed movies, we recommend that Microsoft ventures in the top five most streamed movies as illustrated in the above visualization for an easy penetration into the market.

# %%
#merged data runtime
print(merged_data['runtime_minutes'].isnull().sum())
# Out:
# 0

# %%
#Fill missing data with median to handle outliers
merged_data['runtime_minutes'].fillna(merged_data['runtime_minutes'].median(), inplace=True)
merged_data
# Out:
#             tconst                   primary_title  \
# 0        tt0063540                       Sunghursh
# 0        tt0063540                       Sunghursh
# 0        tt0063540                       Sunghursh
# 1        tt0063540                       Sunghursh
# 1        tt0063540                       Sunghursh
# ...            ...                             ...
# 1030871  tt9916754  Chico Albuquerque - Revelações
# 1030872  tt9916754  Chico Albuquerque - Revelações
# 1030873  tt9916754  Chico Albuquerque - Revelações
# 1030874  tt9916754  Chico Albuquerque - Revelações
# 1030875  tt9916754  Chico Albuquerque - Revelações
#
#                          original_title start_year runtime_minutes  \
# 0                             Sunghursh       2013           175.0
# 0                             Sunghursh       2013           175.0
# 0                             Sunghursh       2013           175.0
# 1                             Sunghursh       2013           175.0
# ...

# %%
merged_data.head()
# Out:
#       tconst primary_title original_title start_year runtime_minutes  genres  \
# 0  tt0063540     Sunghursh      Sunghursh       2013           175.0  Action
# 0  tt0063540     Sunghursh      Sunghursh       2013           175.0   Crime
# 0  tt0063540     Sunghursh      Sunghursh       2013           175.0   Drama
# 1  tt0063540     Sunghursh      Sunghursh       2013           175.0  Action
# 1  tt0063540     Sunghursh      Sunghursh       2013           175.0   Crime
#
#    directors                                  writers ordering     nconst  \
# 0  nm0712540  nm0023551,nm1194313,nm0347899,nm1391276     10.0  nm0006210
# 0  nm0712540  nm0023551,nm1194313,nm0347899,nm1391276     10.0  nm0006210
# 0  nm0712540  nm0023551,nm1194313,nm0347899,nm1391276     10.0  nm0006210
# 1  nm0712540  nm0023551,nm1194313,nm0347899,nm1391276      1.0  nm0474801
# 1  nm0712540  nm0023551,nm1194313,nm0347899,nm1391276      1.0  nm0474801
#
# ...

# %% [markdown]
# We want to check the top 5 writers with an intention of recommending to Microsoft to partner with them

# %%
#checking missing data in writers column
print(merged_data['writers'].isnull().sum())
# Out:
# 243558

# %%
#checking the len of the writers column
len(merged_data['writers'])
# Out:
# 1701332

# %%
merged_data['writers'].fillna('Unknown', inplace=True)

# %%
#reconfirming my writers column
print(merged_data['writers'].isnull().sum())
# Out:
# 0

# %%
#checking missing data in average rating column
print(merged_data['averagerating'].isnull().sum())
# Out:
# 0

# %%
#dropping the nan in the average rating column
average_rating_column= merged_data.dropna(subset=['averagerating'])

# %%
# Group by writers and average rating, and count the number of entries
best_performing_writers = merged_data.groupby(['writers', 'averagerating']).size().reset_index(name='count')

# Sort the DataFrame by average rating in descending order
best_performing_writers_sorted = best_performing_writers.sort_values(by='averagerating', ascending=False)

# Print or use the sorted DataFrame
print(best_performing_writers_sorted)
# Out:
#                                                  writers averagerating  count
# 51952                                nm3372281,nm6543532           nan      6
# 64028                                          nm4345767           nan      6
# 64007                                          nm4343502           nan     10
# 64008                                nm4343502,nm4406647           nan     20
# 64009                      nm4343642,nm4644181,nm3956094           nan      9
# ...                                                  ...           ...    ...
# 77181  nm5590847,nm3087956,nm6979451,nm6979450,nm6979452           1.0     20
# 80781                                          nm6008960           1.0      7
# 12954            nm0620050,nm4923046,nm4923020,nm4923017           1.0     10
# 85576                                          nm6594610           1.0      6
# 0                                                Unknown           1.0    122
#
# [103904 rows x 3 columns]

# %%
# Visualizing the top 6 best writers 
top_6_writers = best_performing_writers_sorted.head(6)

plt.figure(figsize=(10, 6))

plt.barh(top_6_writers['writers'], top_6_writers['count'])
plt.xlabel('Number of Entries')
plt.ylabel('Writers')
plt.title('Top 6 Best Performing Writers')

plt.show()

# %% [markdown]
# Based on the above analysis we have observed that the best 6 writers according to the average ratings are nm3372281,nm6543532,nm4345767,nm434502,nm434502, nm4343502,nm4406647,nm4343642,nm4644181,nm3956094. We recommend that Microsoft reaches out to the writers for a possible partnership

# %% [markdown]
# Next, we want to confirm if there is a correletion between the average rating and runtime minutes with an intent to recommend to microsoft how long the best selling movies usually are!

# %%
merged_data.sample(5)
# Out:
#            tconst                primary_title               original_title  \
# 158202  tt1866143  Duresori: The Voice of East  Duresori: The Voice of East
# 361930  tt2852708                 Project Run!                 Project Run!
# 382715  tt3014528               Targeting Iran               Targeting Iran
# 347758  tt2739032              La méduse rouge              La méduse rouge
# 651061  tt5122590      Change Your Name Ousama      Change Your Name Ousama
#
#        start_year runtime_minutes       genres            directors  \
# 158202       2012           110.0        Drama  nm4375481,nm5682145
# 361930       2013             nan       Comedy            nm3994344
# 382715       2013            71.0  Documentary            nm2535561
# 347758       2013           101.0       Sci-Fi            nm2906184
# 651061       2012            48.0  Documentary            nm6632684
#
#                               writers ordering     nconst         category  \
# ...

# %%
#checking missing data in writers column
print(merged_data['runtime_minutes'].isnull().sum())
# Out:
# 0

# %%
#checking the data types for the runtime minutes 
datatype=merged_data['averagerating'].dtype
datatype
# Out:
# dtype('O')

# %%
#changing the averagerating and runtime data types to integer
merged_data['averagerating'] = pd.to_numeric(merged_data['averagerating'], errors='coerce')
merged_data['runtime_minutes'] = pd.to_numeric(merged_data['runtime_minutes'], errors='coerce')

# %%
sampled_merged_data = merged_data.sample(frac=0.1) 
correlation = sampled_merged_data['averagerating'].corr(sampled_merged_data['runtime_minutes'])
print(f"The correlation between average rating and runtime minutes is: {correlation}")
# Out:
# The correlation between average rating and runtime minutes is: 0.010842172042242214

# %%
#visualizing the correlation
plt.figure(figsize=(8, 6))
plt.scatter(sampled_merged_data['averagerating'], sampled_merged_data['runtime_minutes'], alpha=0.5)
plt.xlabel('Average Rating')
plt.ylabel('Runtime (minutes)')
plt.title('Correlation between Average Rating and Runtime')
plt.show()

# %% [markdown]
# from the analysis above it can be observed that the correlation coefficient of approximately -0.00094 is very close to zero, indicating an extremely weak and essentially negligible linear relationship between the variables.

# %%
#Checking if bom dataset was loaded properly
df.sample(10)
# Out:
#                                title studio  domestic_gross foreign_gross  \
# 3168                       Early Man    LGF       8300000.0      46400000
# 1890                     Home (2015)    Fox     177400000.0     208600000
# 500   My Afternoons with Margueritte  Cohen        667000.0      13600000
# 446                   Shark Night 3D  Rela.      18900000.0      21300000
# 3222                     102 Not Out   Sony       1300000.0      10900000
# 2936                         Collide    ORF       2300000.0       2500000
# 2504               My King (Mon roi)     FM         54100.0       7900000
# 123                  Furry Vengeance   Sum.      17600000.0      18600000
# 2171                    Heneral Luna   Abr.        206000.0           NaN
# 917                   The Collection     LD       6800000.0           NaN
#
#       year
# 3168  2018
# 1890  2015
# 500   2011
# 446   2011
# 3222  2018
# 2936  2017
# 2504  2016
# 123   2010
# 2171  2015
# 917   2012

# %%
#checking  the sum of null datasets
df.isnull().sum()
# Out:
# title                0
# studio               5
# domestic_gross      28
# foreign_gross     1350
# year                 0
# dtype: int64

# %%
#checking unique datatypes in my null dataset
df.nunique()
# Out:
# title             3386
# studio             257
# domestic_gross    1797
# foreign_gross     1204
# year                 9
# dtype: int64

# %%
#cheking bom dataset data info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
#checking a random sample of the bom dataset
df.sample(5)
# Out:
#                     title studio  domestic_gross foreign_gross  year
# 2070             Ladrones    LGF       3100000.0           NaN  2015
# 368      Cowboys & Aliens   Uni.     100200000.0      74600000  2011
# 769        The Impossible   LG/S      19000000.0     161300000  2012
# 2082      Beloved Sisters   MBox         54000.0       2200000  2015
# 1888  Terminator: Genisys   Par.      89800000.0     350800000  2015

# %%
#checking data types to objects
df.dtypes
# Out:
# title              object
# studio             object
# domestic_gross    float64
# foreign_gross      object
# year                int64
# dtype: object

# %%
df.dtypes
# Out:
# title              object
# studio             object
# domestic_gross    float64
# foreign_gross      object
# year                int64
# dtype: object

# %%
#checking null datasets
df.isnull()
# Out:
#       title  studio  domestic_gross  foreign_gross   year
# 0     False   False           False          False  False
# 1     False   False           False          False  False
# 2     False   False           False          False  False
# 3     False   False           False          False  False
# 4     False   False           False          False  False
# ...     ...     ...             ...            ...    ...
# 3382  False   False           False           True  False
# 3383  False   False           False           True  False
# 3384  False   False           False           True  False
# 3385  False   False           False           True  False
# 3386  False   False           False           True  False
#
# [3387 rows x 5 columns]

# %%
#Are there duplicates in the dataset
df.duplicated().sum()
# Out:
# 0

# %%
# Drop the duplicates
df.drop_duplicates(inplace=True)

# %%
#Is there null values in this data? If yes then show it in the heatmap
df.isnull().sum()
# Out:
# title                0
# studio               5
# domestic_gross      28
# foreign_gross     1350
# year                 0
# dtype: int64

# %%
#checking my bom dataset description
df.describe()
# Out:
#        domestic_gross         year
# count    3.359000e+03  3387.000000
# mean     2.874585e+07  2013.958075
# std      6.698250e+07     2.478141
# min      1.000000e+02  2010.000000
# 25%      1.200000e+05  2012.000000
# 50%      1.400000e+06  2014.000000
# 75%      2.790000e+07  2016.000000
# max      9.367000e+08  2018.000000

# %%
df.dtypes
# Out:
# title              object
# studio             object
# domestic_gross    float64
# foreign_gross      object
# year                int64
# dtype: object

# %%
grouped_data = df.groupby('title')['domestic_gross'].sum()
grouped_data
# Out:
# title
# '71                                 1300000.0
# 1,000 Times Good Night                53900.0
# 10 Cloverfield Lane                72100000.0
# 10 Years                             203000.0
# 1001 Grams                            11000.0
#                                      ...
# Zoolander 2                        28800000.0
# Zootopia                          341300000.0
# [Rec] 2                               27800.0
# mother!                            17800000.0
# xXx: The Return of Xander Cage     44900000.0
# Name: domestic_gross, Length: 3386, dtype: float64

# %%
df.columns
# Out:
# Index(['title', 'studio', 'domestic_gross', 'foreign_gross', 'year'], dtype='object')

# %%
# showing null values in a heatmap
sns.heatmap(df.isnull())
plt.show()

# %% [markdown]
# From the above heatmap graphical representation we observe that the column foreign_gross has the highest missing data, it may not be an ideal column to work with and hence we will drop it.

# %% [markdown]
# We are going to look into the top 10 best performing studios and recommend microsoft to partner with them

# %%
df.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
#check missing data in studios
print(df['studio'].isnull().sum())
# Out:
# 5

# %%
#replace the missing values with "Unknown"
df['studio']= df['studio'].fillna("Unknown")
df.sample(5)
# Out:
#                             title studio  domestic_gross foreign_gross  year
# 2710            As I Open My Eyes     KL         31000.0           NaN  2016
# 1694            The German Doctor  Gold.        418000.0       2600000  2014
# 102                   Daybreakers    LGF      30100000.0      21300000  2010
# 2649  Until Forever (Por Siempre)     CZ        105000.0           NaN  2016
# 680      Vidal Sassoon: The Movie     P4         86000.0         38600  2011

# %%
#check missing data in domestic gross
print(df['domestic_gross'].isnull().sum())
# Out:
# 28

# %%
#checking studio data counts
studio_counts = df['studio'].value_counts()
print(studio_counts)
# Out:
# IFC           166
# Uni.          147
# WB            140
# Fox           136
# Magn.         136
#              ...
# E1              1
# PI              1
# ELS             1
# PalT            1
# Synergetic      1
# Name: studio, Length: 258, dtype: int64

# %%
df['studio'] = df['studio'].str.split(',')

# Use the explode function to create separate rows for each genre
df = df.explode('studio')

# Count the individual genres
studio_counts = df['studio'].value_counts().reset_index()

# Rename the columns for clarity
studio_counts.columns = ['studio', 'Count']

# Display the counts
print(studio_counts)
# Out:
#          studio  Count
# 0           IFC    166
# 1          Uni.    147
# 2            WB    140
# 3           Fox    136
# 4         Magn.    136
# ..          ...    ...
# 253          E1      1
# 254          PI      1
# 255         ELS      1
# 256        PalT      1
# 257  Synergetic      1
#
# [258 rows x 2 columns]

# %%
top_10_studios = studio_counts.head(10)

plt.figure(figsize=(12, 6))
sns.barplot(data=top_10_studios, x='Count', y='studio')
# Customize the plot
plt.title('Count of studios')
plt.xlabel('Count')
plt.ylabel('studio')

#rotate the x axis for readability
plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# We are going to look into which studio has been performing the best in the recent years and recommend Microsoft to partner with them

# %%
df.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
#check missing data in year column
print(df['year'].isnull().sum())
# Out:
# 0

# %%
#checking missing data in studio column
print(df['studio'].isnull().sum())
# Out:
# 0

# %%
#checking if the year column contains categorical data
print(df['year'].dtype)
# Out:
# int64

# %%
#changing the year data to numerical data type
df['year'] = df['year'].astype(int)
print(df['year'].dtype)
# Out:
# int32

# %%
# grouping my year and studio data
best_performing_studios = df.groupby(['studio', 'year']).size().reset_index(name='count')
best_performing_studios_sorted = best_performing_studios.sort_values(by='year', ascending=False)

best_performing_studios_sorted
# Out:
#         studio  year  count
# 140      Cohen  2018      5
# 582        STX  2018      8
# 590      Scre.  2018      2
# 624  Trafalgar  2018      1
# 215        FIP  2018      2
# ..         ...   ...    ...
# 263       FoxS  2010      8
# 675      Vita.  2010      1
# 537    Relbig.  2010      4
# 497       Par.  2010     10
# 0           3D  2010      1
#
# [747 rows x 3 columns]

# %%
# Filter the DataFrame to include only the years 2018, 2019, and 2017
filtered_df = df[df['year'].isin([2018, 2019, 2017])]

# Group by studio and year, and count the number of entries
best_performing_studios = filtered_df.groupby(['studio', 'year']).size().reset_index(name='count')

# Sort the DataFrame by year in descending order
best_performing_studios_sorted = best_performing_studios.sort_values(by='year', ascending=True)

# Get the top 10 studios
top_10_studios = best_performing_studios_sorted['studio'].value_counts().nlargest(10).index

# Filter the DataFrame to include only the top 10 studios
top_10_studios_data = best_performing_studios_sorted[best_performing_studios_sorted['studio'].isin(top_10_studios)]

# Create a bar plot using Seaborn
plt.figure(figsize=(10, 6))

sns.barplot(x='count', y='studio', data=top_10_studios_data, hue='year', dodge=False)

# Set labels and title
plt.xlabel('Count')
plt.ylabel('Studio')
plt.title('Top 10 Performing Studios Over the Years')

# Rotate y-axis labels for better readability
plt.yticks(rotation=45)

# Display the plot
plt.show()

# %% [markdown]
# From the above analysis we observe that RAtt, SGem, SPC, STX, SCre, Sony, Strand, Uni, Vita and A24 were really performing well for the years 2018 and 2017, these studios understand the most recent market dynamics of movie production and therefore Microsoft would reach out to them for a possible collaboration.

# %%
df.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %% [markdown]
# We are going to do an analysis of the studios against the domestic gross to figure out which studios perform the best locally, we can then recommend Microsoft to Partner with them for projects locally

# %%
print(df['studio'].isnull().sum())
# Out:
# 0

# %%
#replace the missing values with "Unknown"
df['studio']= df['studio'].fillna("Unknown")
df.sample(5)
# Out:
#               title  studio  domestic_gross foreign_gross  year
# 1348       Lovelace    RTWC        357000.0       1200000  2013
# 2720      Chevalier  Strand         25700.0           NaN  2016
# 3335   Mary Shelley     IFC        109000.0           NaN  2018
# 1535    The Nut Job     ORF      64300000.0      56600000  2014
# 497   Desert Flower     NGE         44300.0      14600000  2011

# %%
print(df['domestic_gross'].isnull().sum())
# Out:
# 28

# %%
#replace the missing values with "Unknown"
df['domestic_gross']= df['domestic_gross'].fillna("Unknown")
df.sample(5)
# Out:
#                                 title studio domestic_gross foreign_gross  \
# 849   The Perks of Being a Wallflower   LG/S     17700000.0      15600000
# 2564                       Lazer Team  Ampl.      1200000.0           NaN
# 2551                       Demolition   FoxS      2000000.0           NaN
# 2507               Southside with You  RAtt.      6300000.0        208000
# 1805                  Life's a Breeze  Magn.         3500.0         99700
#
#       year
# 849   2012
# 2564  2016
# 2551  2016
# 2507  2016
# 1805  2014

# %%
#changing the domestic gross column to int
df['domestic_gross'] = pd.to_numeric(df['domestic_gross'], downcast='integer', errors='coerce')
df.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
best_local_studios = df.groupby('domestic_gross')['studio'].first()
best_local_studios
# Out:
# domestic_gross
# 100.0             Magn.
# 300.0                FM
# 400.0             Magn.
# 500.0          Distrib.
# 600.0             Trib.
#                  ...
# 623400000.0          BV
# 652300000.0        Uni.
# 678800000.0          BV
# 700100000.0          BV
# 936700000.0          BV
# Name: studio, Length: 1797, dtype: object

# %%
print(df['domestic_gross'].dtype)

df['domestic_gross'] = pd.to_numeric(df['domestic_gross'], errors='coerce')

df['domestic_gross'].fillna(0, inplace=True)
# Out:
# float64

# %%
best_local_studios_sorted = df.sort_values(by='domestic_gross', ascending=False)

best_local_studios_sorted
# Out:
#                                title studio  domestic_gross foreign_gross  \
# 1872    Star Wars: The Force Awakens     BV     936700000.0      1,131.60
# 3080                   Black Panther     BV     700100000.0     646900000
# 3079          Avengers: Infinity War     BV     678800000.0      1,369.50
# 1873                  Jurassic World   Uni.     652300000.0      1,019.40
# 727            Marvel's The Avengers     BV     623400000.0     895500000
# ...                              ...    ...             ...           ...
# 936              Lula, Son of Brazil   NYer             0.0       3800000
# 1079                  The Green Wave     RF             0.0         70100
# 1975  Surprise - Journey To The West     AR             0.0      49600000
# 966                   The Cup (2012)   Myr.             0.0       1800000
# 537                            Force   FoxS             0.0       4800000
#
#       year
# 1872  2015
# 3080  2018
# 3079  2018
# 1873  2015
# 727   2012
# ...

# %%
# Get the first 15 studios
top_studios = best_local_studios_sorted['studio'].head(20)

# Filter the DataFrame to include only the top 15 studios
top_studios_data = best_local_studios_sorted[best_local_studios_sorted['studio'].isin(top_studios)]

# Create a bar plot using Seaborn
plt.figure(figsize=(10, 6))
sns.barplot(x='domestic_gross', y='studio', data=top_studios_data)

# Set labels and title
plt.xlabel('Domestic Gross')
plt.ylabel('Studio')
plt.title('Top Studios by Domestic Gross')

# Display the plot
plt.show()

# %% [markdown]
# From the above analysis we observe that BV studio is the best selling studio locally, in the year 2015 they had sales worth 936700000.0, we therefore recommend that Microsoft could reach out to them for a possible partnership for local movie production

# %% [markdown]
# Recommendations
#
# Genre-based content strategy
#
# Microsoft should focus on producing movies in genres with demonstrated high popularity, specifically drama, documentary and comedy. This strategy will facilitate an easier market entry and maximize audience engagement.
#
# Collaboration with successful studios
#
# Exploring collaborations with top-performing studios, as identified in the analysis, will provide Microsoft with valuable industry knowledge and enhance the quality of its productions. This strategic partnership can drive success in the competitive movie production market
#
# Partnership with BV Studio for Local Production
#
# Establishing a partnership with BV Studio, the best-selling studio locally in 2015, offers a unique opportunity for Microsoft to leverage their proven success and tap into the local market effectively.
#
# Insights on top writers
#
# Based on our analysis, the following writers have received consistently high average ratings: nm3372281,nm6543532,nm4345767,nm434502,nm4343502,nm4406647. We highly recommend that Microsoft reaches out to these writers for potential partnerships. Their track record of high average ratings indicates a strong potential for creating engaging and well-received content.
#
# Potential Studio collaborations
#
# Studios that demonstrated exceptional performance in the years 2018 and 2017: RAtt, SGem, SPC, STX, SCre, Sony, Strand, Uni, Vita, A24. Based on their proven success and understanding of recent market dynamics, we strongly recommend that Microsoft explores collaboration opportunities with these studios. This strategic partnership can enhance Microsoft's position in the competitive movie production industry.

# %% [markdown]
# Conclusion
#
# Entering the movie production industry presents a promising opportunity for Microsoft to diversify business portfolio and capitalize on the growing demand for engaging content. By implementing the recommended strategies and leveraging key partnerships, Microsoft can establish a strong presence in the competitive movie production market.
